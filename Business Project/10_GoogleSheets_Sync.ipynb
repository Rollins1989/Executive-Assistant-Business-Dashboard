# %%
# !pip install gspread
# !pip install gspread_dataframe
# !pip install google-auth
# !pip install google-auth-oauthlib
# !pip install google-auth-httplib2
# !pip install openpyxl
# Out:
# ...
#
#    ---------------------------------------- 0/5 [oauthlib]
#    ---------------- ----------------------- 2/5 [google-auth]
#    ---------------- ----------------------- 2/5 [google-auth]
#    ---------------------------------------- 5/5 [gspread]
#
# ...
#
#    ---------------------------------------- 2/2 [google-auth-httplib2]
#
# ...

# %%
import pandas as pd

import gspread

import os

from google.oauth2.service_account import Credentials

from gspread_dataframe import set_with_dataframe

print("Libraries Loaded Successfully")
# Out:
# Libraries Loaded Successfully

# %%
project_folder="Executive_Assistant_Business_Dashboard"

data_folder=os.path.join(project_folder,"data")

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\Kuldeep\Projects\Business Project

# %%
import os

for file in os.listdir("Executive_Assistant_Business_Dashboard"):
    print(file)
# Out:
# charts
# dashboard
# data
# output
# reports

# %%
project_folder = os.getcwd()

data_folder = os.path.join(project_folder, "data")
reports_folder = os.path.join(project_folder, "reports")
charts_folder = os.path.join(project_folder, "charts")
output_folder = os.path.join(project_folder, "output")

# %%
scope = [
    "https://www.googleapis.com/auth/spreadsheets",
    "https://www.googleapis.com/auth/drive"
]

json_file = os.path.join(
    project_folder,
    "spartan-studio-500815-q8-c14811e18769.json"
)

creds = Credentials.from_service_account_file(
    json_file,
    scopes=scope
)

client = gspread.authorize(creds)

print("✅ Google Authentication Successful")
# Out:
# ✅ Google Authentication Successful

# %%
import os

print(os.listdir(project_folder))
# Out:
# ['.ipynb_checkpoints', '01_Create_Database.ipynb', '02_Master_Data_Generation.ipynb', '03_Meeting_Tracker_Dashboard.ipynb', '04_Followup_Tracker_Dashboard.ipynb', '05_Task_Dashboard.ipynb', '06_Vendor_Tracker.ipynb', '07_Expense_Tracker.ipynb', '08_Calendar_Analytics.ipynb', '09_MIS_Dashboard.ipynb', '10_GoogleSheets_Sync.ipynb', 'Executive_Assistant_Business_Dashboard', 'spartan-studio-500815-q8-c14811e18769.json']
